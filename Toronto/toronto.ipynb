# %% [markdown]
# <a href="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"><img src = "https://cdn.torontolife.com/wp-content/uploads/2016/10/toronto-skyline-803x603-1476458932.jpg" width = 140, align = "center"></a>
#
# # Clustering Neighborhoods in Toronto
# ### Autor: Patrick Franco Alves

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item1">Install the required packages</a>
#
# 2. <a href="#item2">BeautifulSoup to scrap the data</a>
#
# 3. <a href="#item3">Storing in pandas dataset</a>
#
# 4. <a href="#item4">Map of Toronto using Folium</a>
#
# 5. <a href="#item4">Pizza Clusters of Toronto</a>
#
# </font>
# </div>

# %% [markdown]
# ## 1.  Install the required packages

# %%
! conda install -c anaconda beautifulsoup4 --yes
#! conda install -c conda-forge geopy --yes 
#! conda install -c anaconda lxml --yes
#! conda install -c conda-forge geopy --yes
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     soupsieve-1.9.3            |           py36_0          60 KB  anaconda
#     openssl-1.1.1              |       h7b6447c_0         5.0 MB  anaconda
#     certifi-2019.9.11          |           py36_0         154 KB  anaconda
#     beautifulsoup4-4.8.0       |           py36_0         147 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     soupsieve:      1.9.3-py36_0      anaconda
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.3-py37_0                  --> 4.8.0-py36_0     anaconda
#     certifi:        2019.6.16-py36_1  conda-forge --> 2019.9.11-py36_0 anaconda
#     openssl:        1.1.1c-h516909a_0 conda-forge --> 1.1.1-h7b6447c_0 anaconda
#
#
# Downloading and Extracting Packages
# soupsieve-1.9.3      | 60 KB     | ##################################### | 100%
# openssl-1.1.1        | 5.0 MB    | ##################################### | 100%
# certifi-2019.9.11    | 154 KB    | ##################################### | 100%
# beautifulsoup4-4.8.0 | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         238 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0        conda-forge
#     geopy:         1.20.0-py_0      conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:       2019.9.11-py36_0 anaconda    --> 2019.9.11-py36_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:       1.1.1-h7b6447c_0 anaconda    --> 1.1.1c-h516909a_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.9.11          |           py36_0         154 KB  anaconda
#     lxml-4.3.0                 |   py36hefd8a0e_0         1.5 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         1.6 MB
#
# The following packages will be UPDATED:
#
#     certifi: 2019.9.11-py36_0     conda-forge --> 2019.9.11-py36_0     anaconda
#     lxml:    4.2.5-py37hefd8a0e_0             --> 4.3.0-py36hefd8a0e_0 anaconda
#     openssl: 1.1.1c-h516909a_0    conda-forge --> 1.1.1-h7b6447c_0     anaconda
#
#
# Downloading and Extracting Packages
# certifi-2019.9.11    | 154 KB    | ##################################### | 100%
# lxml-4.3.0           | 1.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#
# The following packages will be UPDATED:
#
#     certifi: 2019.9.11-py36_0 anaconda --> 2019.9.11-py36_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl: 1.1.1-h7b6447c_0 anaconda --> 1.1.1c-h516909a_0 conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## 2.  BeautifulSoup to scrap the data

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from bs4 import BeautifulSoup

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ## 2. Uses BeautifulSoup to scrap the data.

# %%
website_text = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

soup = BeautifulSoup(website_text, "html5lib")

# %%
table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')

# %% [markdown]
# ## 3.  Storing in pandas dataset

# %%
table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')

data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

df = pd.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df = df[~df['PostalCode'].isnull()]  # to filter out bad rows

# %%
df.head(10)
# Out:
#    PostalCode           Borough     Neighbourhood
# 1         M1A      Not assigned      Not assigned
# 2         M2A      Not assigned      Not assigned
# 3         M3A        North York         Parkwoods
# 4         M4A        North York  Victoria Village
# 5         M5A  Downtown Toronto      Harbourfront
# 6         M5A  Downtown Toronto       Regent Park
# 7         M6A        North York  Lawrence Heights
# 8         M6A        North York    Lawrence Manor
# 9         M7A      Queen's Park      Not assigned
# 10        M8A      Not assigned      Not assigned

# %%
df[df.Borough != 'Not assigned'].groupby('Neighbourhood').count()
# Out:
#                   PostalCode  Borough
# Neighbourhood
# Adelaide                   1        1
# Agincourt                  1        1
# Agincourt North            1        1
# Albion Gardens             1        1
# Alderwood                  1        1
# ...                      ...      ...
# Woodbine Heights           1        1
# York Mills                 1        1
# York Mills West            1        1
# York University            1        1
# Yorkville                  1        1
#
# [209 rows x 2 columns]

# %%
df2 = df[df.Borough != 'Not assigned']

# %%
print("Before deleting Not assigned rows",df.shape)
print("After deleting Not assigned rows",df2.shape)
# Out:
# Before deleting Not assigned rows (288, 3)
# After deleting Not assigned rows (211, 3)

# %% [markdown]
# ##### Use geopy to get the latitude and longitude of Toronto.

# %%
from geopy.geocoders import Nominatim

# %%
# convert an address into latitude and longitude values
address = 'Toronto, Ontario'

#Budapest Park

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Latitude and longitude of Toronto: {}, {}.'.format(latitude, longitude))
# Out:
# Latitude and longitude of Toronto: 43.653963, -79.387207.

# %% [markdown]
# ## 4. Map of Toronto using folium

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=12)

# %%
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !wget -q -O 'Geospatial_Coordinates.csv' http://cocl.us/Geospatial_data

#http://cocl.us/Geospatial_data

print('Data downloaded!')
# Out:
# Data downloaded!

# %%
geo_df = pd.read_csv('Geospatial_Coordinates.csv')
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#merge
geo_df.columns
# Out:
# Index(['Postal Code', 'Latitude', 'Longitude'], dtype='object')

# %%
df2.columns
# Out:
# Index(['PostalCode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
neighborhoods = df2.merge(geo_df, left_on='PostalCode', right_on='Postal Code')

# %%
neighborhoods.head()
# Out:
#   PostalCode           Borough     Neighbourhood Postal Code   Latitude  \
# 0        M3A        North York         Parkwoods         M3A  43.753259
# 1        M4A        North York  Victoria Village         M4A  43.725882
# 2        M5A  Downtown Toronto      Harbourfront         M5A  43.654260
# 3        M5A  Downtown Toronto       Regent Park         M5A  43.654260
# 4        M6A        North York  Lawrence Heights         M6A  43.718518
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.360636
# 4 -79.464763

# %%
#import folium  
#from IPython.display import HTML, display

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
display(map_newyork)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_newyork.save('map_newyork.html')

# %%
map_newyork.save("map_newyork.png")

# %% [markdown]
# ## 5. Pizza Clusters of Toronto

# %%
CLIENT_ID = 'USC23TI2Y3K0WLFYXPJUXXEJVZ4NUEMT3CR5T3ZCNTJ3IB55' # your Foursquare ID
CLIENT_SECRET = 'U2QVNANSIRP4OBT5MWECVSUP0VR1PVEQLDKY5S4HY4CNCP0S' # your Foursquare Secret
VERSION = '20191013'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: USC23TI2Y3K0WLFYXPJUXXEJVZ4NUEMT3CR5T3ZCNTJ3IB55
# CLIENT_SECRET:U2QVNANSIRP4OBT5MWECVSUP0VR1PVEQLDKY5S4HY4CNCP0S

# %%
address = 'Toronto Tower'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.64635315 -79.4023620504047

# %%
print(latitude, longitude)
# Out:
# 43.64635315 -79.4023620504047

# %%
search_query = 'pizza'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# pizza .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=USC23TI2Y3K0WLFYXPJUXXEJVZ4NUEMT3CR5T3ZCNTJ3IB55&client_secret=U2QVNANSIRP4OBT5MWECVSUP0VR1PVEQLDKY5S4HY4CNCP0S&ll=43.64635315,-79.4023620504047&v=20191013&query=pizza&radius=1000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5da475b70d2be7002c877c13'},
#  'response': {'venues': [{'id': '4bc3a04cabf49521650bc493',
#     'name': 'Pizza Pizza',
#     'location': {'address': '655 Queen St W',
#      'lat': 43.64711589206853,
#      'lng': -79.40415196491139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64711589206853,
#        'lng': -79.40415196491139}],
#      'distance': 167,
#      'postalCode': 'M6J 1E8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['655 Queen St W', 'Toronto ON M6J 1E8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4af23cabf964a520d4e621e3',
#     'name': 'Pizza Rustica Restaurant & Bar',
#     'location': {'address': '37 Blue Jays Way',
#      'lat': 43.64491920354413,
#      'lng': -79.3918436177755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64491920354413,
#        'lng': -79.3918436177755}],
#      'distance': 862,
#      'postalCode': 'M5V 3P5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['37 Blue Jays Way', 'Toronto ON M5V 3P5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4adc9f99f964a520092e21e3',
#     'name': "Mamma's Pizza",
#     'location': {'address': '405 Richmond St. W',
#      'crossStreet': 'at Spadina Ave.',
#      'lat': 43.64794272203376,
#      'lng': -79.3956474811735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64794272203376,
#        'lng': -79.3956474811735}],
#      'distance': 569,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['405 Richmond St. W (at Spadina Ave.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4dde735f7d8bb03c06b3db73',
#     'name': 'Boston Pizza',
#     'location': {'address': '250 Front St',
#      'crossStreet': 'John St',
#      'lat': 43.64405883528329,
#      'lng': -79.38881541663336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64405883528329,
#        'lng': -79.38881541663336}],
#      'distance': 1120,
#      'postalCode': 'M5V 3G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Front St (John St)',
#       'Toronto ON M5V 3G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4b7f161bf964a5206e1530e3',
#     'name': 'Pizza Nova',
#     'location': {'address': '371 Front Street W',
#      'crossStreet': 'at Blue Jay Way',
#      'lat': 43.64327168873745,
#      'lng': -79.39183585267101,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64327168873745,
#        'lng': -79.39183585267101}],
#      'distance': 914,
#      'postalCode': 'M5V 3S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['371 Front Street W (at Blue Jay Way)',
#       'Toronto ON M5V 3S8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4aeb18d8f964a5204bbe21e3',
#     'name': 'Pizzaiolo',
#     'location': {'address': '521 King St. W',
#      'crossStreet': 'at Brant St.',
#      'lat': 43.64479341856585,
#      'lng': -79.3982296189393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64479341856585,
#        'lng': -79.3982296189393}],
#      'distance': 375,
#      'postalCode': 'M5V 1K4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['521 King St. W (at Brant St.)',
#       'Toronto ON M5V 1K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4b02ec72f964a5200c4b22e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '540 King Street West',
#      'lat': 43.6449428004504,
#      'lng': -79.3980232213905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6449428004504,
#        'lng': -79.3980232213905}],
#      'distance': 383,
#      'postalCode': 'M5V 1M3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['540 King Street West',
#       'Toronto ON M5V 1M3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '580a5dfb38fa4875ae680a3f',
#     'name': 'Pizza Thick & The Ice Cream Bake Shop',
#     'location': {'address': '536 Queen St W',
#      'lat': 43.647512,
#      'lng': -79.402509,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647512,
#        'lng': -79.402509}],
#      'distance': 129,
#      'postalCode': 'M5V 2B5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['536 Queen St W', 'Toronto ON M5V 2B5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4ae09982f964a520d08021e3',
#     'name': 'Pizzaiolo',
#     'location': {'address': '609 Queen Street West',
#      'crossStreet': 'Bathurst',
#      'lat': 43.64745689946616,
#      'lng': -79.40247635728825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64745689946616,
#        'lng': -79.40247635728825}],
#      'distance': 123,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['609 Queen Street West (Bathurst)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4beb2f0162c0c92811d4e1d4',
#     'name': 'Pizza Aiolo',
#     'location': {'address': '609 queen street west',
#      'lat': 43.647499,
#      'lng': -79.402481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647499,
#        'lng': -79.402481}],
#      'distance': 127,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['609 queen street west', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4bba5d947421a59380b5c340',
#     'name': "Domino's Pizza",
#     'location': {'address': '51 Niagara St',
#      'crossStreet': 'at Bathurst St',
#      'lat': 43.64188774570393,
#      'lng': -79.40196162252661,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64188774570393,
#        'lng': -79.40196162252661}],
#      'distance': 498,
#      'postalCode': 'M5V 1C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['51 Niagara St (at Bathurst St)',
#       'Toronto ON M5V 1C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4c2aaa9aae6820a186be1643',
#     'name': 'Pizza Hut',
#     'location': {'address': '720 King Street West',
#      'lat': 43.64357261100789,
#      'lng': -79.40444192345056,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64357261100789,
#        'lng': -79.40444192345056}],
#      'distance': 351,
#      'postalCode': 'M5V 2T3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['720 King Street West',
#       'Toronto ON M5V 2T3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4ee279790cd6638ac53a6157',
#     'name': 'Amato Pizza',
#     'location': {'address': '534 Queen Street West',
#      'lat': 43.64769026542162,
#      'lng': -79.40269947052002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64769026542162,
#        'lng': -79.40269947052002}],
#      'distance': 151,
#      'postalCode': 'M5V 2B5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['534 Queen Street West',
#       'Toronto ON M5V 2B5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '5b77a3dc78782c002c492322',
#     'name': 'Blaze Pizza',
#     'location': {'address': '150 John Street',
#      'lat': 43.64906304786478,
#      'lng': -79.39084761040422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64906304786478,
#        'lng': -79.39084761040422}],
#      'distance': 975,
#      'postalCode': 'M5V 3C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 John Street', 'Toronto ON M5V 3C3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '5644dbaa498e7f7534154326',
#     'name': 'Maker Pizza',
#     'location': {'address': '59 Cameron St',
#      'lat': 43.6504011331197,
#      'lng': -79.39804047841302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6504011331197,
#        'lng': -79.39804047841302}],
#      'distance': 569,
#      'postalCode': 'M5T 2H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['59 Cameron St', 'Toronto ON M5T 2H1', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4eacda774690615f265eec46',
#     'name': 'Pizza Nova',
#     'location': {'address': '901 King St W',
#      'crossStreet': 'at Strachan Ave',
#      'lat': 43.642010853785024,
#      'lng': -79.41190916306661,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642010853785024,
#        'lng': -79.41190916306661}],
#      'distance': 908,
#      'postalCode': 'M5V 3H5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['901 King St W (at Strachan Ave)',
#       'Toronto ON M5V 3H5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4ce87211d99f721e8fadb073',
#     'name': 'Pizzaiolo Gourmet Pizza',
#     'location': {'address': '624 Queen Street West',
#      'lat': 43.6469300616867,
#      'lng': -79.40551866346723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6469300616867,
#        'lng': -79.40551866346723}],
#      'distance': 262,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['624 Queen Street West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '5b7331b00d8a0f002c4849bf',
#     'name': 'Za Pizza Bistro',
#     'location': {'address': '290 Adelaide Street West',
#      'lat': 43.64787,
#      'lng': -79.391136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64787,
#        'lng': -79.391136}],
#      'distance': 919,
#      'postalCode': 'M5V 1P6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['290 Adelaide Street West',
#       'Toronto ON M5V 1P6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '58269bf33398744fe41b9dce',
#     'name': 'Village Pizza',
#     'location': {'address': '761 Dundas St W',
#      'lat': 43.652065,
#      'lng': -79.406425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652065,
#        'lng': -79.406425}],
#      'distance': 715,
#      'postalCode': 'M6J 1T9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['761 Dundas St W', 'Toronto ON M6J 1T9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '5aa59c977564f726ae4069c6',
#     'name': 'Big Trouble Pizza',
#     'location': {'address': '235 Spadina Ave',
#      'crossStreet': 'Dundas St. W',
#      'lat': 43.651347,
#      'lng': -79.39702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651347,
#        'lng': -79.39702}],
#      'distance': 702,
#      'postalCode': 'M5T 2E2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['235 Spadina Ave (Dundas St. W)',
#       'Toronto ON M5T 2E2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4b60916bf964a52015ee29e3',
#     'name': 'Pizza Pizza',
#     'location': {'address': '340 Front St W',
#      'crossStreet': 'Blue Jays Way',
#      'lat': 43.64340720952727,
#      'lng': -79.39124851566606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64340720952727,
#        'lng': -79.39124851566606}],
#      'distance': 953,
#      'postalCode': 'M5V 3W7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['340 Front St W (Blue Jays Way)',
#       'Toronto ON M5V 3W7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4ae89ed7f964a520efb021e3',
#     'name': 'Panzerotto Pizza',
#     'location': {'address': '404 Queen St W',
#      'lat': 43.648508480284356,
#      'lng': -79.39702846996235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648508480284356,
#        'lng': -79.39702846996235}],
#      'distance': 492,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['404 Queen St W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '54558851498ecfacfe2d44fc',
#     'name': 'Queen Margherita Pizza',
#     'location': {'address': '772 Dundas St W',
#      'crossStreet': 'Bathurst',
#      'lat': 43.65205447497852,
#      'lng': -79.40726328734823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65205447497852,
#        'lng': -79.40726328734823}],
#      'distance': 747,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['772 Dundas St W (Bathurst)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '589767b22ec36429cb234bf1',
#     'name': 'Tosto QuickFire Pizza Pasta',
#     'location': {'lat': 43.647806,
#      'lng': -79.396355,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647806,
#        'lng': -79.396355}],
#      'distance': 510,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '5690363d498e0b868217831d',
#     'name': "Jz's Pizza",
#     'location': {'lat': 43.645145,
#      'lng': -79.389296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645145,
#        'lng': -79.389296}],
#      'distance': 1061,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4e191e10e4cd49a7e3f0da9f',
#     'name': 'Mr Right Pizza and Doner',
#     'location': {'lat': 43.652137,
#      'lng': -79.40627402950219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652137,
#        'lng': -79.40627402950219}],
#      'distance': 716,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4aeef7caf964a520ecd421e3',
#     'name': 'Pizza Rustica Boutique',
#     'location': {'address': '232 wellington street west',
#      'crossStreet': 'John',
#      'lat': 43.64511516109716,
#      'lng': -79.38940583644242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64511516109716,
#        'lng': -79.38940583644242}],
#      'distance': 1052,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['232 wellington street west (John)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4e45556a483b03d090d09cab',
#     'name': 'Panzerotto Pizza',
#     'location': {'address': '299 Bathurst St.',
#      'crossStreet': 'Dundas and Bathurst',
#      'lat': 43.65371433072711,
#      'lng': -79.40587520599365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65371433072711,
#        'lng': -79.40587520599365}],
#      'distance': 866,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['299 Bathurst St. (Dundas and Bathurst)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '51c1f3b8498ec6e59a2bd589',
#     'name': "Gino's Pizza",
#     'location': {'address': '399 Bathurst St',
#      'crossStreet': 'Dundas',
#      'lat': 43.652698173255004,
#      'lng': -79.40599999627591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652698173255004,
#        'lng': -79.40599999627591}],
#      'distance': 764,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['399 Bathurst St (Dundas)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4c50b1489d642d7f854050dc',
#     'name': "Ciccio's Pizza & Pasta",
#     'location': {'address': '796 Dundas Street West',
#      'lat': 43.651803765965376,
#      'lng': -79.408314200848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651803765965376,
#        'lng': -79.408314200848}],
#      'distance': 773,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['796 Dundas Street West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4e2f47201838f1c552c3b5f7',
#     'name': "Gino's Pizza",
#     'location': {'address': '869 Queen St. W',
#      'crossStreet': 'at Bellwoods Ave.',
#      'lat': 43.646846252875406,
#      'lng': -79.41132642774959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646846252875406,
#        'lng': -79.41132642774959}],
#      'distance': 724,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['869 Queen St. W (at Bellwoods Ave.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4ee0f612f9f418e8e914d6f2',
#     'name': '241 Pizza Delivery',
#     'location': {'address': '327 Queen St W',
#      'lat': 43.64795421908404,
#      'lng': -79.3906831741333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64795421908404,
#        'lng': -79.3906831741333}],
#      'distance': 957,
#      'postalCode': 'M5V 2A4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['327 Queen St W', 'Toronto ON M5V 2A4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '57c5fa24cd102fdc7db35473',
#     'name': "Domino's Pizza",
#     'location': {'address': '344 Front St W',
#      'crossStreet': 'Spadina',
#      'lat': 43.643426,
#      'lng': -79.392029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643426,
#        'lng': -79.392029}],
#      'distance': 893,
#      'postalCode': 'M5V 3W7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['344 Front St W (Spadina)',
#       'Toronto ON M5V 3W7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '540c809f498e8f0de56ae791',
#     'name': 'PIzzailo',
#     'location': {'lat': 43.646324157714844,
#      'lng': -79.39910125732422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646324157714844,
#        'lng': -79.39910125732422}],
#      'distance': 262,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '500ee248e4b060e7f2b5bedf',
#     'name': 'Pizza700',
#     'location': {'lat': 43.645816,
#      'lng': -79.394826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645816,
#        'lng': -79.394826}],
#      'distance': 609,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '52b47f80498e7f921fe518c9',
#     'name': 'Pizzaiolo',
#     'location': {'address': '123 Spadina Ave',
#      'lat': 43.64713760208766,
#      'lng': -79.39566190827182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64713760208766,
#        'lng': -79.39566190827182}],
#      'distance': 546,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Spadina Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False},
#    {'id': '4b2d3727f964a52047d124e3',
#     'name': 'Pizzaiolo',
#     'location': {'address': '270 Adelaide St. W',
#      'crossStreet': 'at John St',
#      'lat': 43.64783852702828,
#      'lng': -79.39029271145894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64783852702828,
#        'lng': -79.39029271145894}],
#      'distance': 986,
#      'postalCode': 'M5H 1X6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['270 Adelaide St. W (at John St)',
#       'Toronto ON M5H 1X6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571059127',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                            name  \
# 0  4bc3a04cabf49521650bc493                     Pizza Pizza
# 1  4af23cabf964a520d4e621e3  Pizza Rustica Restaurant & Bar
# 2  4adc9f99f964a520092e21e3                   Mamma's Pizza
# 3  4dde735f7d8bb03c06b3db73                    Boston Pizza
# 4  4b7f161bf964a5206e1530e3                      Pizza Nova
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571059127    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571059127    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571059127    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571059127    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1571059127    False
#
#      location.address  location.lat  location.lng  \
# 0      655 Queen St W     43.647116    -79.404152
# 1    37 Blue Jays Way     43.644919    -79.391844
# 2  405 Richmond St. W     43.647943    -79.395647
# 3        250 Front St     43.644059    -79.388815
# 4  371 Front Street W     43.643272    -79.391836
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.64711589206853...                167
# 1  [{'label': 'display', 'lat': 43.64491920354413...                862
# 2  [{'label': 'display', 'lat': 43.64794272203376...                569
# 3  [{'label': 'display', 'lat': 43.64405883528329...               1120
# 4  [{'label': 'display', 'lat': 43.64327168873745...                914
#
#   location.postalCode location.cc location.city location.state  \
# 0             M6J 1E8          CA       Toronto             ON
# 1             M5V 3P5          CA       Toronto             ON
# 2                 NaN          CA       Toronto             ON
# 3             M5V 3G5          CA       Toronto             ON
# 4             M5V 3S8          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada       [655 Queen St W, Toronto ON M6J 1E8, Canada]
# 1           Canada     [37 Blue Jays Way, Toronto ON M5V 3P5, Canada]
# 2           Canada  [405 Richmond St. W (at Spadina Ave.), Toronto...
# 3           Canada  [250 Front St (John St), Toronto ON M5V 3G5, C...
# 4           Canada  [371 Front Street W (at Blue Jay Way), Toronto...
#
#   location.crossStreet
# 0                  NaN
# 1                  NaN
# 2      at Spadina Ave.
# 3              John St
# 4      at Blue Jay Way

# %%
dataframe.shape
# Out:
# (37, 17)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name          categories  \
# 0                             Pizza Pizza         Pizza Place
# 1          Pizza Rustica Restaurant & Bar         Pizza Place
# 2                           Mamma's Pizza         Pizza Place
# 3                            Boston Pizza         Pizza Place
# 4                              Pizza Nova         Pizza Place
# 5                               Pizzaiolo         Pizza Place
# 6                             Pizza Pizza         Pizza Place
# 7   Pizza Thick & The Ice Cream Bake Shop         Pizza Place
# 8                               Pizzaiolo         Pizza Place
# 9                             Pizza Aiolo         Pizza Place
# 10                         Domino's Pizza         Pizza Place
# 11                              Pizza Hut         Pizza Place
# 12                            Amato Pizza         Pizza Place
# 13                            Blaze Pizza         Pizza Place
# 14                            Maker Pizza         Pizza Place
# 15                             Pizza Nova         Pizza Place
# 16                Pizzaiolo Gourmet Pizza         Pizza Place
# 17                        Za Pizza Bistro         Pizza Place
# 18                          Village Pizza         Pizza Place
# 19                      Big Trouble Pizza         Pizza Place
# 20                            Pizza Pizza         Pizza Place
# 21                       Panzerotto Pizza         Pizza Place
# 22                 Queen Margherita Pizza  Italian Restaurant
# 23            Tosto QuickFire Pizza Pasta  Italian Restaurant
# 24                             Jz's Pizza  Italian Restaurant
# 25               Mr Right Pizza and Doner                None
# 26                 Pizza Rustica Boutique  Italian Restaurant
# 27                       Panzerotto Pizza         Pizza Place
# 28                           Gino's Pizza         Pizza Place
# 29                 Ciccio's Pizza & Pasta         Pizza Place
# 30                           Gino's Pizza         Pizza Place
# 31                     241 Pizza Delivery         Pizza Place
# 32                         Domino's Pizza         Pizza Place
# 33                               PIzzailo         Pizza Place
# 34                               Pizza700         Pizza Place
# 35                              Pizzaiolo         Pizza Place
# 36                              Pizzaiolo         Pizza Place
#
#                        address        lat        lng  \
# 0               655 Queen St W  43.647116 -79.404152
# 1             37 Blue Jays Way  43.644919 -79.391844
# 2           405 Richmond St. W  43.647943 -79.395647
# 3                 250 Front St  43.644059 -79.388815
# 4           371 Front Street W  43.643272 -79.391836
# 5               521 King St. W  43.644793 -79.398230
# 6         540 King Street West  43.644943 -79.398023
# 7               536 Queen St W  43.647512 -79.402509
# 8        609 Queen Street West  43.647457 -79.402476
# 9        609 queen street west  43.647499 -79.402481
# 10               51 Niagara St  43.641888 -79.401962
# 11        720 King Street West  43.643573 -79.404442
# 12       534 Queen Street West  43.647690 -79.402699
# 13             150 John Street  43.649063 -79.390848
# 14               59 Cameron St  43.650401 -79.398040
# 15               901 King St W  43.642011 -79.411909
# 16       624 Queen Street West  43.646930 -79.405519
# 17    290 Adelaide Street West  43.647870 -79.391136
# 18             761 Dundas St W  43.652065 -79.406425
# 19             235 Spadina Ave  43.651347 -79.397020
# 20              340 Front St W  43.643407 -79.391249
# 21              404 Queen St W  43.648508 -79.397028
# 22             772 Dundas St W  43.652054 -79.407263
# 23                         NaN  43.647806 -79.396355
# 24                         NaN  43.645145 -79.389296
# 25                         NaN  43.652137 -79.406274
# 26  232 wellington street west  43.645115 -79.389406
# 27            299 Bathurst St.  43.653714 -79.405875
# 28             399 Bathurst St  43.652698 -79.406000
# 29      796 Dundas Street West  43.651804 -79.408314
# 30             869 Queen St. W  43.646846 -79.411326
# 31              327 Queen St W  43.647954 -79.390683
# 32              344 Front St W  43.643426 -79.392029
# 33                         NaN  43.646324 -79.399101
# 34                         NaN  43.645816 -79.394826
# 35             123 Spadina Ave  43.647138 -79.395662
# 36          270 Adelaide St. W  43.647839 -79.390293
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.64711589206853...       167    M6J 1E8
# 1   [{'label': 'display', 'lat': 43.64491920354413...       862    M5V 3P5
# 2   [{'label': 'display', 'lat': 43.64794272203376...       569        NaN
# 3   [{'label': 'display', 'lat': 43.64405883528329...      1120    M5V 3G5
# 4   [{'label': 'display', 'lat': 43.64327168873745...       914    M5V 3S8
# 5   [{'label': 'display', 'lat': 43.64479341856585...       375    M5V 1K4
# 6   [{'label': 'display', 'lat': 43.6449428004504,...       383    M5V 1M3
# 7   [{'label': 'display', 'lat': 43.647512, 'lng':...       129    M5V 2B5
# 8   [{'label': 'display', 'lat': 43.64745689946616...       123        NaN
# 9   [{'label': 'display', 'lat': 43.647499, 'lng':...       127        NaN
# 10  [{'label': 'display', 'lat': 43.64188774570393...       498    M5V 1C2
# 11  [{'label': 'display', 'lat': 43.64357261100789...       351    M5V 2T3
# 12  [{'label': 'display', 'lat': 43.64769026542162...       151    M5V 2B5
# 13  [{'label': 'display', 'lat': 43.64906304786478...       975    M5V 3C3
# 14  [{'label': 'display', 'lat': 43.6504011331197,...       569    M5T 2H1
# 15  [{'label': 'display', 'lat': 43.64201085378502...       908    M5V 3H5
# 16  [{'label': 'display', 'lat': 43.6469300616867,...       262        NaN
# 17  [{'label': 'display', 'lat': 43.64787, 'lng': ...       919    M5V 1P6
# 18  [{'label': 'display', 'lat': 43.652065, 'lng':...       715    M6J 1T9
# 19  [{'label': 'display', 'lat': 43.651347, 'lng':...       702    M5T 2E2
# 20  [{'label': 'display', 'lat': 43.64340720952727...       953    M5V 3W7
# 21  [{'label': 'display', 'lat': 43.64850848028435...       492        NaN
# 22  [{'label': 'display', 'lat': 43.65205447497852...       747        NaN
# 23  [{'label': 'display', 'lat': 43.647806, 'lng':...       510        NaN
# 24  [{'label': 'display', 'lat': 43.645145, 'lng':...      1061        NaN
# 25  [{'label': 'display', 'lat': 43.652137, 'lng':...       716        NaN
# 26  [{'label': 'display', 'lat': 43.64511516109716...      1052        NaN
# 27  [{'label': 'display', 'lat': 43.65371433072711...       866        NaN
# 28  [{'label': 'display', 'lat': 43.65269817325500...       764        NaN
# 29  [{'label': 'display', 'lat': 43.65180376596537...       773        NaN
# 30  [{'label': 'display', 'lat': 43.64684625287540...       724        NaN
# 31  [{'label': 'display', 'lat': 43.64795421908404...       957    M5V 2A4
# 32  [{'label': 'display', 'lat': 43.643426, 'lng':...       893    M5V 3W7
# 33  [{'label': 'display', 'lat': 43.64632415771484...       262        NaN
# 34  [{'label': 'display', 'lat': 43.645816, 'lng':...       609        NaN
# 35  [{'label': 'display', 'lat': 43.64713760208766...       546        NaN
# 36  [{'label': 'display', 'lat': 43.64783852702828...       986    M5H 1X6
#
#     cc     city state country  \
# 0   CA  Toronto    ON  Canada
# 1   CA  Toronto    ON  Canada
# 2   CA  Toronto    ON  Canada
# 3   CA  Toronto    ON  Canada
# 4   CA  Toronto    ON  Canada
# 5   CA  Toronto    ON  Canada
# 6   CA  Toronto    ON  Canada
# 7   CA  Toronto    ON  Canada
# 8   CA  Toronto    ON  Canada
# 9   CA  Toronto    ON  Canada
# 10  CA  Toronto    ON  Canada
# 11  CA  Toronto    ON  Canada
# 12  CA  Toronto    ON  Canada
# 13  CA  Toronto    ON  Canada
# 14  CA  Toronto    ON  Canada
# 15  CA  Toronto    ON  Canada
# 16  CA  Toronto    ON  Canada
# 17  CA  Toronto    ON  Canada
# 18  CA  Toronto    ON  Canada
# 19  CA  Toronto    ON  Canada
# 20  CA  Toronto    ON  Canada
# 21  CA  Toronto    ON  Canada
# 22  CA  Toronto    ON  Canada
# 23  CA      NaN   NaN  Canada
# 24  CA      NaN   NaN  Canada
# 25  CA  Toronto    ON  Canada
# 26  CA  Toronto    ON  Canada
# 27  CA  Toronto    ON  Canada
# 28  CA  Toronto    ON  Canada
# 29  CA  Toronto    ON  Canada
# 30  CA  Toronto    ON  Canada
# 31  CA  Toronto    ON  Canada
# 32  CA  Toronto    ON  Canada
# 33  CA  Toronto    ON  Canada
# 34  CA      NaN   NaN  Canada
# 35  CA  Toronto    ON  Canada
# 36  CA  Toronto    ON  Canada
#
#                                      formattedAddress          crossStreet  \
# 0        [655 Queen St W, Toronto ON M6J 1E8, Canada]                  NaN
# 1      [37 Blue Jays Way, Toronto ON M5V 3P5, Canada]                  NaN
# 2   [405 Richmond St. W (at Spadina Ave.), Toronto...      at Spadina Ave.
# 3   [250 Front St (John St), Toronto ON M5V 3G5, C...              John St
# 4   [371 Front Street W (at Blue Jay Way), Toronto...      at Blue Jay Way
# 5   [521 King St. W (at Brant St.), Toronto ON M5V...         at Brant St.
# 6   [540 King Street West, Toronto ON M5V 1M3, Can...                  NaN
# 7        [536 Queen St W, Toronto ON M5V 2B5, Canada]                  NaN
# 8   [609 Queen Street West (Bathurst), Toronto ON,...             Bathurst
# 9         [609 queen street west, Toronto ON, Canada]                  NaN
# 10  [51 Niagara St (at Bathurst St), Toronto ON M5...       at Bathurst St
# 11  [720 King Street West, Toronto ON M5V 2T3, Can...                  NaN
# 12  [534 Queen Street West, Toronto ON M5V 2B5, Ca...                  NaN
# 13      [150 John Street, Toronto ON M5V 3C3, Canada]                  NaN
# 14        [59 Cameron St, Toronto ON M5T 2H1, Canada]                  NaN
# 15  [901 King St W (at Strachan Ave), Toronto ON M...      at Strachan Ave
# 16        [624 Queen Street West, Toronto ON, Canada]                  NaN
# 17  [290 Adelaide Street West, Toronto ON M5V 1P6,...                  NaN
# 18      [761 Dundas St W, Toronto ON M6J 1T9, Canada]                  NaN
# 19  [235 Spadina Ave (Dundas St. W), Toronto ON M5...         Dundas St. W
# 20  [340 Front St W (Blue Jays Way), Toronto ON M5...        Blue Jays Way
# 21               [404 Queen St W, Toronto ON, Canada]                  NaN
# 22   [772 Dundas St W (Bathurst), Toronto ON, Canada]             Bathurst
# 23                                           [Canada]                  NaN
# 24                                           [Canada]                  NaN
# 25                               [Toronto ON, Canada]                  NaN
# 26  [232 wellington street west (John), Toronto ON...                 John
# 27  [299 Bathurst St. (Dundas and Bathurst), Toron...  Dundas and Bathurst
# 28     [399 Bathurst St (Dundas), Toronto ON, Canada]               Dundas
# 29       [796 Dundas Street West, Toronto ON, Canada]                  NaN
# 30  [869 Queen St. W (at Bellwoods Ave.), Toronto ...    at Bellwoods Ave.
# 31       [327 Queen St W, Toronto ON M5V 2A4, Canada]                  NaN
# 32  [344 Front St W (Spadina), Toronto ON M5V 3W7,...              Spadina
# 33                               [Toronto ON, Canada]                  NaN
# 34                                           [Canada]                  NaN
# 35              [123 Spadina Ave, Toronto ON, Canada]                  NaN
# 36  [270 Adelaide St. W (at John St), Toronto ON M...           at John St
#
#                           id
# 0   4bc3a04cabf49521650bc493
# 1   4af23cabf964a520d4e621e3
# 2   4adc9f99f964a520092e21e3
# 3   4dde735f7d8bb03c06b3db73
# 4   4b7f161bf964a5206e1530e3
# 5   4aeb18d8f964a5204bbe21e3
# 6   4b02ec72f964a5200c4b22e3
# 7   580a5dfb38fa4875ae680a3f
# 8   4ae09982f964a520d08021e3
# 9   4beb2f0162c0c92811d4e1d4
# 10  4bba5d947421a59380b5c340
# 11  4c2aaa9aae6820a186be1643
# 12  4ee279790cd6638ac53a6157
# 13  5b77a3dc78782c002c492322
# 14  5644dbaa498e7f7534154326
# 15  4eacda774690615f265eec46
# 16  4ce87211d99f721e8fadb073
# 17  5b7331b00d8a0f002c4849bf
# 18  58269bf33398744fe41b9dce
# 19  5aa59c977564f726ae4069c6
# 20  4b60916bf964a52015ee29e3
# 21  4ae89ed7f964a520efb021e3
# 22  54558851498ecfacfe2d44fc
# 23  589767b22ec36429cb234bf1
# 24  5690363d498e0b868217831d
# 25  4e191e10e4cd49a7e3f0da9f
# 26  4aeef7caf964a520ecd421e3
# 27  4e45556a483b03d090d09cab
# 28  51c1f3b8498ec6e59a2bd589
# 29  4c50b1489d642d7f854050dc
# 30  4e2f47201838f1c552c3b5f7
# 31  4ee0f612f9f418e8e914d6f2
# 32  57c5fa24cd102fdc7db35473
# 33  540c809f498e8f0de56ae791
# 34  500ee248e4b060e7f2b5bedf
# 35  52b47f80498e7f921fe518c9
# 36  4b2d3727f964a52047d124e3

# %%
poutine2 = dataframe_filtered[['lat','lng','formattedAddress']]

# %%
poutine2.head()
# Out:
#          lat        lng                                   formattedAddress
# 0  43.647116 -79.404152       [655 Queen St W, Toronto ON M6J 1E8, Canada]
# 1  43.644919 -79.391844     [37 Blue Jays Way, Toronto ON M5V 3P5, Canada]
# 2  43.647943 -79.395647  [405 Richmond St. W (at Spadina Ave.), Toronto...
# 3  43.644059 -79.388815  [250 Front St (John St), Toronto ON M5V 3G5, C...
# 4  43.643272 -79.391836  [371 Front Street W (at Blue Jay Way), Toronto...

# %%
poutine2.shape
# Out:
# (37, 3)

# %%
map_newyork2 = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, address in zip(poutine2['lat'], poutine2['lng'], poutine2['formattedAddress']):
    label = '{}'.format(address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork2)  
    
display(map_newyork2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_newyork2.save('map_newyork2.html')

# %%
map_newyork2.save("map_newyork2.png")
